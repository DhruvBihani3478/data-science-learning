# %% [markdown]
# # Module 5: Modules and Packages Assignments
# ## Lesson 5.1: Importing Modules
# ### Assignment 1: Importing and Using Modules
#
# Import the `math` module and use it to calculate the square root of 25 and the sine of 90 degrees.

# %%
import math
print(math.sqrt(25))
print(math.sin(math.radians(90)))
# Out:
# 5.0
# 1.0

# %% [markdown]
# ### Assignment 2: Aliasing Modules
#
# Import the `datetime` module with an alias and use it to print the current date and time.

# %%
import datetime as dt
curr=dt.datetime.now()
print(curr)
# Out:
# 2026-07-07 11:12:30.935833

# %% [markdown]
# ### Assignment 3: Importing Specific Functions
#
# Import the `randint` function from the `random` module and use it to generate a random integer between 1 and 100.

# %%
import random

print(random.randint(1,100))
# Out:
# 62

# %% [markdown]
# ### Assignment 4: Importing Multiple Functions
#
# Import the `sqrt` and `pow` functions from the `math` module and use them to calculate the square root of 16 and 2 raised to the power of 3.

# %%
from math import sqrt,pow
print(sqrt(16))
print(pow(2,3))
# Out:
# 4.0
# 8.0

# %% [markdown]
# ### Assignment 5: Handling Import Errors
#
# Write code that attempts to import a non-existent module and gracefully handles the import error by printing an error message.

# %%
try:
    import non_existent_module
except ImportError as e:
    print(f"Error importing module: {e}")
# Out:
# Error importing module: No module named 'non_existent_module'

# %% [markdown]
# ## Lesson 5.2: Standard Library Overview
# ### Assignment 6: Working with the `os` Module
#
# Use the `os` module to create a new directory, list the contents of the current directory, and remove the newly created directory.

# %%
import os
os.mkdir('new')
print(os.listdir('.'))
os.rmdir('new')
print(os.listdir('.'))
# Out:
# ['advancefunctions.ipynb', 'Control_Flow_Assignment.ipynb', 'dictionaries_assignment.ipynb', 'Inbuilt-dtata-structure.ipynb', 'list_assignment.ipynb', 'new', 'packagesquestion.ipynb', 'practise_functions.ipynb', 'Python_Basics.ipynb', 'sample.txt', 'sets_assignment.ipynb', 'tuple_assignment.ipynb']
# ['advancefunctions.ipynb', 'Control_Flow_Assignment.ipynb', 'dictionaries_assignment.ipynb', 'Inbuilt-dtata-structure.ipynb', 'list_assignment.ipynb', 'packagesquestion.ipynb', 'practise_functions.ipynb', 'Python_Basics.ipynb', 'sample.txt', 'sets_assignment.ipynb', 'tuple_assignment.ipynb']

# %% [markdown]
# ### Assignment 7: Working with the `sys` Module
#
# Use the `sys` module to print the Python version currently in use and the command-line arguments passed to the script.

# %%
import sys

print(f"Python version: {sys.version}")
print(f"Command-line arguments: {sys.argv}")
# Out:
# Python version: 3.12.13 | packaged by Anaconda, Inc. | (main, Mar 19 2026, 20:16:45) [MSC v.1942 64 bit (AMD64)]
# Command-line arguments: ['C:\\Users\\dhruv\\AppData\\Roaming\\Python\\Python312\\site-packages\\ipykernel_launcher.py', '--f=c:\\Users\\dhruv\\AppData\\Roaming\\jupyter\\runtime\\kernel-v3a4624195aa3ee14e6c5fc4770c989db3f5b02833.json']

# %% [markdown]
# ### Assignment 8: Working with the `math` Module
#
# Use the `math` module to calculate the greatest common divisor (GCD) of two numbers and the factorial of a number.

# %%
print(math.gcd(30,90))
print(math.factorial(8))
# Out:
# 30
# 40320

# %% [markdown]
# ### Assignment 9: Working with the `datetime` Module
#
# Use the `datetime` module to print the current date, calculate the date 100 days from today, and determine the day of the week for a given date.

# %%
import datetime
now=datetime.datetime.now()
print(now)
print(now+ datetime.timedelta(days=100))
given_date=datetime.date(2026,7,7)
print(f"Day of the week for 2026-07-07: {given_date.strftime('%A')}")
# Out:
# 2026-07-07 11:39:20.055510
# 2026-10-15 11:39:20.055510
# Day of the week for 2026-07-07: Tuesday

# %% [markdown]
# ### Assignment 10: Working with the `random` Module
#
# Use the `random` module to generate a list of 5 random numbers between 1 and 50 and shuffle the elements of a list.

# %%
import random
random_numbers = [random.randint(1, 50) for _ in range(5)]
print(random_numbers)

lst = [1, 2, 3, 4, 5]
random.shuffle(lst)
print(lst)
# Out:
# [16, 4, 15, 12, 6]
# [1, 5, 2, 4, 3]

# %% [markdown]
# ## Lesson 5.3: Creating and Using Packages
# ### Assignment 11: Creating a Simple Package
#
# Create a package named `mypackage` with two modules: `module1` and `module2`. `module1` should contain a function that adds two numbers, and `module2` should contain a function that multiplies two numbers. Write code to use these functions.a

# %%
from mypackage import module1, module2
print(module1.addition(2,3))
print(module2.multiplication(8,9))
# Out:
# 5
# 72

# %% [markdown]
# ### Assignment 12: Using `__init__.py`
#
# Modify the `mypackage` package to include an `__init__.py` file that imports the functions from `module1` and `module2`. Write code to use these functions.

# %%
from mypackage import addition, multiplication

print(addition(2, 3))
print(multiplication(2, 3))
# Out:
# 5
# 6

# %% [markdown]
# ### Assignment 13: Relative Imports
#
# Create a subpackage named `subpackage` within `mypackage` and `module3` to `subpackage`.

# %%
from mypackage.subpackage import module3
print(module3.subtraction(9,2))
# Out:
# 7

# %% [markdown]
# ### Assignment 14: Importing from a Package
#
# Write code to import and use the functions from `mypackage` without explicitly importing `module3`.

# %%
from mypackage import subtraction
print(subtraction(9,2))
# Out:
# 7

# %% [markdown]
# ### Assignment 15: Handling Package Import Errors
#
# Write code that attempts to import a non-existent function from `mypackage` and gracefully handles the import error by printing an error message.

# %%
try:
    from mypackage import non_existent_function
except ImportError as e:
    print(f"Error importing function: {e}")
# Out:
# Error importing function: No module named 'mypackage'
